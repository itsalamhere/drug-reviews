# %% [markdown]
# # EDA: Exploratory Data Analysis + Data Cleaning -- `DrugReviews.csv`
#
# In this project, we'll be exploring the dataset and clean them for the purpose of dashboard and sentiment prediction. To recall, the data has been collected from [drugs.com](drugs.com) and stored in a single CSV file by [Ahmed et al., (2023)](https://data.mendeley.com/datasets/64cc5w5dxy/1) . The dataset contains 392510 unique reviews along with:
# - `MedicineName` -- the name of the drug,
# - `MedicineFor` -- the condition for which the drug was taken,
# - `ReviewDate` -- when the review's posted,
# - `UserName` -- who posted the review,
# - `IntakeTime` -- how long the drug was taken for,
# - `Reviews` -- how the user perceives the drug,
# - `ReviewLength` -- how many characters are in the reviews,
# - `Rating` -- score by the user, scaled from `1-10`,
# - `NumberOfLikes` -- the credibility of the review in the form of likes.
#
# Let's dive in, shall we?

# %% [markdown]
# To clean the data, we need several modules:
# - `numpy` and `pandas` for data manipulation, and
# - `re` for cleaning text in a character-detail.

# %%
import re
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('DrugReviews.csv')
pd.options.display.max_colwidth = 50

# %%
df
# Out:
#                             MedicineName           MedicineFor ReviewDate  \
# 0       12 Hour Nasal Decongestant Spray  For Nasal Congestion  26-Jan-21
# 1       12 Hour Nasal Decongestant Spray  For Nasal Congestion  19-Aug-22
# 2       12 Hour Nasal Decongestant Spray  For Nasal Congestion  28-Apr-18
# 3                                  5-HTP           For Anxiety   3-May-20
# 4                                  5-HTP           For Anxiety  11-Jul-19
# ...                                  ...                   ...        ...
# 392505             ZzzQuil for Insomnia          Not Mentioned  23-Sep-20
# 392506             ZzzQuil for Insomnia          Not Mentioned  26-Sep-22
# 392507             ZzzQuil for Insomnia          Not Mentioned  12-Jun-20
# 392508             ZzzQuil for Insomnia          Not Mentioned  18-Aug-20
# 392509             ZzzQuil for Insomnia          Not Mentioned  22-May-20
#
#         UserName                   IntakeTime  \
# 0           xano                Not Specified
# 1       Breat...       Taken for 1 to 2 years
# 2            Abe  Taken for less than 1 month
# 3         Andres  Taken for less than 1 month
# 4          Shawn                Not Specified
# ...          ...                          ...
# 392505     emano  Taken for less than 1 month
# 392506  ZzzQu...  Taken for less than 1 month
# 392507  Annon...                    12-Jun-20
# 392508    Sleepy  Taken for less than 1 month
# 392509     AJano  Taken for less than 1 month
#
#                                                   Reviews  ReviewLength  \
# 0       This is very effective IF you can get the cove...            52
# 1       Actually I use the generic brand of the 12 hou...           319
# 2       Cap took 20 minutes to open process was frustr...           373
# 3       Hi everyone\n'10 / 105-HTPFor Anxiety23129-Oct...           623
# 4       Took SSRI (Prozac) for Anxiety/Depression for ...           156
# ...                                                   ...           ...
# 392505  I hate zzzquill. I took multiple doses one nig...           218
# 392506  Desperately in need of sleep & decided to take...           234
# 392507  I have insomnia for the past several months an...           228
# 392508  I personally wouldn’t recommend this to my wor...           325
# 392509  1st time using ZzzQuil it worked and I was sur...           678
#
#         Rating  NumberOfLikes
# 0            6              0
# 1           10              0
# 2            1              0
# 3           10            345
# 4            9            229
# ...        ...            ...
# 392505       1              8
# 392506       1              3
# 392507       1              8
# 392508       1              6
# 392509       5              6
#
# [392510 rows x 9 columns]

# %%
df.shape
# Out:
# (392510, 9)

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 10    110256
# 1      82266
# 9      54327
# 8      39585
# 2      20853
# 7      20323
# 5      19822
# 3      17802
# 6      14731
# 4      12545
# Name: count, dtype: int64

# %%
df.sort_values(['NumberOfLikes', 'ReviewLength', 'Rating'], ascending=False)
# Out:
#          MedicineName                                        MedicineFor  \
# 160841     Fluoxetine                 Prozac (fluoxetine) for Depression
# 305810         Prozac                                     For Depression
# 160864     Fluoxetine                 Prozac (fluoxetine) for Depression
# 386906         Zoloft                                     For Depression
# 324768     Sertraline                 Zoloft (sertraline) for Depression
# ...               ...                                                ...
# 58783       Cefdinir                                    For Strep Throat
# 155653     Ezetimibe                                For High Cholesterol
# 151559  Etonogestrel          Nexplanon (etonogestrel) for Birth Control
# 255479  Multivitamin   Lipoflavonoid (multivitamin) for Dietary Suppl...
# 261940     Nexplanon                                   For Birth Control
#
#        ReviewDate   UserName                   IntakeTime  \
# 160841  20-Aug-20   READT...                Not Specified
# 305810  20-Aug-20   READT...                Not Specified
# 160864  20-Aug-20   READT...                    20-Aug-20
# 386906   9-Sep-19   Saved...                Not Specified
# 324768   9-Sep-19   Saved...                     9-Sep-19
# ...           ...        ...                          ...
# 58783   10-Jan-21       Ruth  Taken for less than 1 month
# 155653  16-Dec-22       1347                Not Specified
# 151559  22-Feb-17   Kirst...                Not Specified
# 255479   7-Nov-21  Anonymous      Taken for 1 to 6 months
# 261940  22-Feb-17   Kirst...                Not Specified
#
#                                                   Reviews  ReviewLength  \
# 160841  Even though I always said I was never going to...           487
# 305810  Even though I always said I was never going to...           487
# 160864  Even though I always said I was never going to...           487
# 386906  I’m 36 and I’ve dealt with depression my entir...           186
# 324768  I’m 36 and I’ve dealt with depression my entir...           186
# ...                                                   ...           ...
# 58783                                                   I             1
# 155653                                                  I             1
# 151559                                                  I             1
# 255479                                                  I             1
# 261940                                                  I             1
#
#         Rating  NumberOfLikes
# 160841      10           3555
# 305810      10           3555
# 160864      10           3545
# 386906      10           3199
# 324768      10           3190
# ...        ...            ...
# 58783        2              0
# 155653       2              0
# 151559       1              0
# 255479       1              0
# 261940       1              0
#
# [392510 rows x 9 columns]

# %% [markdown]
# ## `IntakeTime`

# %%
df['IntakeTime'].value_counts()
# Out:
# IntakeTime
# Not Specified                   143399
# Taken for less than 1 month      83287
# Taken for 1 to 6 months          65065
# Taken for 6 months to 1 year     21971
# Taken for 1 to 2 years           18733
#                                  ...
# 18-Jun-23                            1
# 7-Jun-23                             1
# 25-Oct-22                            1
# 3-Nov-21                             1
# 8-Sep-20                             1
# Name: count, Length: 5032, dtype: int64

# %%
df['IntakeTime'].value_counts()[8:]
# Out:
# IntakeTime
# 2-Nov-16     22
# 5-Nov-09     21
# 28-Jul-16    20
# 20-Jan-12    20
# 27-Jan-16    19
#              ..
# 18-Jun-23     1
# 7-Jun-23      1
# 25-Oct-22     1
# 3-Nov-21      1
# 8-Sep-20      1
# Name: count, Length: 5024, dtype: int64

# %%
regex_find_date = re.compile('\d{1,2}-.{3}-\d{2}')

df.loc[df['IntakeTime'].str.contains(regex_find_date), :]
# Out:
#                  MedicineName                       MedicineFor ReviewDate  \
# 88                   Abilify               For Bipolar Disorder   4-Jan-12
# 101                  Abilify       For Schizoaffective Disorder  28-Dec-20
# 103                  Abilify                     For Depression  22-Oct-09
# 118            Acetaminophen   Tylenol (acetaminophen) for Pain  13-Oct-09
# 128                  Abilify      For Major Depressive Disorder  15-Feb-18
# ...                       ...                               ...        ...
# 392491  ZzzQuil for Insomnia                      Not Mentioned  31-Jan-21
# 392492  ZzzQuil for Insomnia                      Not Mentioned  25-Aug-19
# 392494  ZzzQuil for Insomnia                      Not Mentioned   3-Oct-18
# 392499  ZzzQuil for Insomnia                      Not Mentioned  27-May-17
# 392507  ZzzQuil for Insomnia                      Not Mentioned  12-Jun-20
#
#          UserName IntakeTime  \
# 88      Anonymous   4-Jan-12
# 101       Skeptic  28-Dec-20
# 103      becky...  22-Oct-09
# 118       la23409  13-Oct-09
# 128      Twing...  15-Feb-18
# ...           ...        ...
# 392491    jasmine  31-Jan-21
# 392492   Feli_...  25-Aug-19
# 392494      Lucky   3-Oct-18
# 392499        LAG  27-May-17
# 392507   Annon...  12-Jun-20
#
#                                                   Reviews  ReviewLength  \
# 88      Starting on day two of treatment I felt progre...           112
# 101     Terrible drug. Caused me to have seizures with...           102
# 103     I don't think this drug is working for my depr...            90
# 118                          Best pain killer ever known.            28
# 128     I haven't experienced any changes with this me...            55
# ...                                                   ...           ...
# 392491  I suffer from depression & anxiety so I also h...           352
# 392492  I used to work overnight so now I suffer from ...           651
# 392494  Diphenhydramine is a fantastic sleep aid but y...           989
# 392499  I usually work a 10 hr shift in the afternoon ...           169
# 392507  I have insomnia for the past several months an...           228
#
#         Rating  NumberOfLikes
# 88           1             13
# 101          1              4
# 103          1             14
# 118         10             30
# 128          1              9
# ...        ...            ...
# 392491      10             24
# 392492       1             32
# 392494       8             25
# 392499       4             23
# 392507       1              8
#
# [25036 rows x 9 columns]

# %% [markdown]
# On `IntakeTime`, we have a data with format of `<Date>`--seems like the users input the same date as `ReviewDate`. We can't know sure when they consume the drug specifically, so we'll include them to `Not Specified`.

# %%
df.loc[df['IntakeTime']
       .str.contains(regex_find_date), 
          'IntakeTime'] = 'Not Specified'

# %%
df['IntakeTime'].value_counts()
# Out:
# IntakeTime
# Not Specified                   168435
# Taken for less than 1 month      83287
# Taken for 1 to 6 months          65065
# Taken for 6 months to 1 year     21971
# Taken for 1 to 2 years           18733
# Taken for 2 to 5 years           18049
# Taken for 5 to 10 years           8694
# Taken for 10 years or more        8276
# Name: count, dtype: int64

# %% [markdown]
# ## Drug Names: `MedicineFor` and `MedicineName`

# %%
pd.DataFrame(df['MedicineFor'].value_counts())[:25]
# Out:
#                                                     count
# MedicineFor
# For Birth Control                                   26772
# For Depression                                      12009
# For Anxiety                                          9791
# For Weight Loss (Obesity/Overweight)                 8157
# Not Mentioned                                        7573
# For Pain                                             6796
# For Acne                                             6666
# For Insomnia                                         6575
# For Bipolar Disorder                                 5614
# Nexplanon (etonogestrel) for Birth Control           4472
# For Diabetes, Type 2                                 4444
# For High Blood Pressure                              4375
# For Vaginal Yeast Infection                          4370
# For Emergency Contraception                          3859
# For ADHD                                             3526
# For Major Depressive Disorder                        3082
# For Anxiety and Stress                               2966
# For Urinary Tract Infection                          2477
# Plan B One-Step (levonorgestrel) for Emergency ...   2444
# For Migraine Prevention                              2378
# For Chronic Pain                                     2310
# For Constipation                                     2260
# For Panic Disorder                                   2223
# For Generalized Anxiety Disorder                     2191
# For Abnormal Uterine Bleeding                        2147

# %%
pd.DataFrame(
    df.loc[df['MedicineFor']
      .str.contains('Birth Control'), 
              'MedicineFor'].value_counts())
# Out:
#                                                     count
# MedicineFor
# For Birth Control                                   26772
# Nexplanon (etonogestrel) for Birth Control           4472
# Mirena (levonorgestrel) for Birth Control            1798
# Implanon (etonogestrel) for Birth Control            1570
# Lo Loestrin Fe (ethinyl estradiol / norethindro...   1473
# ...                                                   ...
# Estrostep Fe (ethinyl estradiol / norethindrone...      1
# Gemmily (ethinyl estradiol / norethindrone) for...      1
# Larin 1.5/30 (ethinyl estradiol / norethindrone...      1
# Brevicon (ethinyl estradiol / norethindrone) fo...      1
# Nor-QD (norethindrone) for Birth Control                1
#
# [224 rows x 1 columns]

# %%
pd.DataFrame(
    df.loc[~df['MedicineFor']
      .str.contains(' for |For '), 
               'MedicineFor'].value_counts(ascending=False))
# Out:
#                                               count
# MedicineFor
# Not Mentioned                                  7573
# Yaz (drospirenone / ethinyl estradiol)          910
# Yasmin (drospirenone / ethinyl estradiol)       555
# Geodon (ziprasidone)                            354
# Gianvi (drospirenone / ethinyl estradiol)       279
# ...                                             ...
# Zetia (ezetimibe)                                 1
# Repatha (evolocumab)                              1
# Lodine (etodolac)                                 1
# Lo/Ovral-28 (ethinyl estradiol / norgestrel)      1
# Ajovy (fremanezumab)                              1
#
# [829 rows x 1 columns]

# %%
pd.DataFrame(df['MedicineName'].value_counts(ascending=False))
# Out:
#                                                     count
# MedicineName
# Levonorgestrel                                       9369
# Ethinyl estradiol / norethindrone                    7273
# Etonogestrel                                         6082
# Ethinyl estradiol / norgestimate                     5343
# Ethinyl estradiol / levonorgestrel                   4708
# ...                                                   ...
# Sabril                                                  1
# Epsom Salt                                              1
# Sodium chloride ophthalmic                              1
# Rabies vaccine, purified chick embryo cell for ...      1
# Rheumatrex Dose Pack                                    1
#
# [4715 rows x 1 columns]

# %%
pd.DataFrame(
    df.loc[df['MedicineName']
      .str.contains(' for '), 
              'MedicineName'].value_counts(ascending=False))[:20]
# Out:
#                                                     count
# MedicineName
# Drospirenone / ethinyl estradiol for Birth Cont...   1523
# Drospirenone / ethinyl estradiol for Acne             647
# Yaz for Birth Control                                 453
# Yasmin for Birth Control                              318
# Mavyret for Hepatitis C                               307
# Ziprasidone for Bipolar Disorder                      273
# Yaz for Acne                                          258
# Drospirenone / ethinyl estradiol for Premenstru...    229
# Zoledronic acid for Osteoporosis                      225
# Zofran for Nausea/Vomiting                            195
# Yasmin for Acne                                       183
# Rybelsus for Diabetes, Type 2                         162
# Zolmitriptan for Migraine                             143
# Yaz for Premenstrual Dysphoric Disorder               121
# Zaleplon for Insomnia                                 120
# Rhofade for Rosacea                                   119
# Maxalt for Migraine                                   112
# Abacavir / dolutegravir / lamivudine for HIV In...    107
# Drospirenone / ethinyl estradiol for Menstrual ...    103
# Restoril for Insomnia                                 100

# %%
pd.DataFrame(
    df.loc[df['MedicineName']
      .str.contains('\('), 
              'MedicineName'].value_counts(ascending=False))
# Out:
#                                           count
# MedicineName
# Sars-cov-2 (covid-19) mrna-1273 vaccine      22
# Chorionic gonadotropin (hcg)                 14
# Humulin R U-500 (Concentrated)                8
# C1 esterase inhibitor (human)                 7
# Sars-cov-2 (covid-19) mrna-1273 vaccine       5
# Rho (d) immune globulin                       4
# Boostrix (Tdap)                               3

# %% [markdown]
# ### Insights for Data Cleaning
#
# As we can see in there are four formats of data in both columns of `MedicineName` and `MedicineFor`:
#
# * Format 1 -- complete: `<Brand> (<GenericName>) for <Usage>`,
# * Format 2 -- no brand: `For <Usage>`,
# * Format 3 -- no usage: `<Brand> (<GenericName>)` and `Not Mentioned`
#
# To could give us a better insight on the data, we'll split the data into three new columns:
#
# * `MedicineUsedFor`,
# * `MedicineBrandName`, and
# * `MedicineGenericName`
#
# And then, we'll split the data from both `MedicineFor` and `MedicineName`, and then fill all the relevant data to the three columns.

# %% [markdown]
# ### Data Cleaning: `MedicineFor`

# %%
mask_mf_1 =  df['MedicineFor'].str.contains(' for ')       ## Format 1
mask_mf_2 =  df['MedicineFor'].str.contains('For ')        ## Format 2
mask_mf_3 = ~df['MedicineFor'].str.contains(' for |For ')  ## Format 3 & 4

# %%
## Split `MedicineFor` into two parts:

## Treatment 1: `<Brand> (<GenericName>) for <MedicineFor>`
medicinefor_with_name = (
    df.loc[mask_mf_1, 'MedicineFor']
        .str.split(' for ', expand=True, n=1)
).rename(columns={0: "Medicine", 1: 'MedicineUsedFor'})

medicinefor_with_name[[
    'MedicineBrandName', 'MedicineGenericName']] = (
        medicinefor_with_name['Medicine']
            .str.replace(')', '')
            .str.split(' \(', n=1, expand=True)
)

# %%
medicinefor_with_name
# Out:
#                                       Medicine             MedicineUsedFor  \
# 70                         Orencia (abatacept)        Rheumatoid Arthritis
# 79                         Orencia (abatacept)        Rheumatoid Arthritis
# 80                         Orencia (abatacept)        Rheumatoid Arthritis
# 81                         Orencia (abatacept)        Rheumatoid Arthritis
# 110                5-HTP (5-hydroxytryptophan)                     Anxiety
# ...                                        ...                         ...
# 391341  Shingrix (zoster vaccine, inactivated)  Herpes Zoster, Prophylaxis
# 391342  Shingrix (zoster vaccine, inactivated)  Herpes Zoster, Prophylaxis
# 391343  Shingrix (zoster vaccine, inactivated)  Herpes Zoster, Prophylaxis
# 391344  Shingrix (zoster vaccine, inactivated)  Herpes Zoster, Prophylaxis
# 391345  Shingrix (zoster vaccine, inactivated)  Herpes Zoster, Prophylaxis
#
#        MedicineBrandName          MedicineGenericName
# 70               Orencia                    abatacept
# 79               Orencia                    abatacept
# 80               Orencia                    abatacept
# 81               Orencia                    abatacept
# 110                5-HTP          5-hydroxytryptophan
# ...                  ...                          ...
# 391341          Shingrix  zoster vaccine, inactivated
# 391342          Shingrix  zoster vaccine, inactivated
# 391343          Shingrix  zoster vaccine, inactivated
# 391344          Shingrix  zoster vaccine, inactivated
# 391345          Shingrix  zoster vaccine, inactivated
#
# [158152 rows x 4 columns]

# %%
medicinefor_with_name['MedicineBrandName'].unique()
# Out:
# array(['Orencia', '5-HTP', 'Tylenol', ..., 'Edluar', 'Zolpimist',
#        'Zostavax'], dtype=object)

# %%
medicinefor_with_name.loc[
    medicinefor_with_name['MedicineBrandName'].str.endswith(' '),
'MedicineBrandName'].unique()
# Out:
# array([], dtype=object)

# %%
## Treatment 2: `For <MedicineFor>`
medicinefor_no_name = (
    df.loc[mask_mf_2, 'MedicineFor']
        .str.split('For ', expand=True, n=1)
).rename(columns={0: "Medicine", 1: 'MedicineUsedFor'})

## Define the rest with '' (blank)
medicinefor_no_name[[
    'Medicine', 'MedicineBrandName', 'MedicineGenericName']] = np.nan

# %%
medicinefor_no_name
# Out:
#         Medicine   MedicineUsedFor  MedicineBrandName  MedicineGenericName
# 0            NaN  Nasal Congestion                NaN                  NaN
# 1            NaN  Nasal Congestion                NaN                  NaN
# 2            NaN  Nasal Congestion                NaN                  NaN
# 3            NaN           Anxiety                NaN                  NaN
# 4            NaN           Anxiety                NaN                  NaN
# ...          ...               ...                ...                  ...
# 392448       NaN          Insomnia                NaN                  NaN
# 392449       NaN          Insomnia                NaN                  NaN
# 392450       NaN          Insomnia                NaN                  NaN
# 392451       NaN          Insomnia                NaN                  NaN
# 392452       NaN          Insomnia                NaN                  NaN
#
# [220338 rows x 4 columns]

# %%
medicinefor_no_name['MedicineBrandName'].unique()
# Out:
# array([nan])

# %%
## Treatment 3: `<Brand> (<GenericName>)` and `Not Mentioned`
medicinefor_no_for = pd.DataFrame(
    df.loc[mask_mf_3, 'MedicineFor']
).rename(columns={'MedicineFor': 'Medicine'})

medicinefor_no_for[[
    'MedicineUsedFor', 'MedicineBrandName', 'MedicineGenericName']] = np.nan

## 3.1: <Brand> (<GenericName>)
medicinefor_no_for[[
    'MedicineBrandName', 'MedicineGenericName']] = (
        medicinefor_no_for['Medicine']
            .str.replace(')', '')
            .str.split(' \(', n=1, expand=True)
)

## 3.2: `Not Mentioned` 
medicinefor_no_for.loc[
    medicinefor_no_for['Medicine'] == 'Not Mentioned',
   ['MedicineBrandName', 'MedicineGenericName']] = np.nan

medicinefor_no_for.loc[
    medicinefor_no_for['Medicine'] != 'Not Mentioned',
                              'MedicineUsedFor'] = np.nan

# %%
medicinefor_no_for[medicinefor_no_for['Medicine'].str.contains(' \(')]
# Out:
#                                       Medicine  MedicineUsedFor  \
# 279                5-HTP (5-hydroxytryptophan)              NaN
# 293                5-HTP (5-hydroxytryptophan)              NaN
# 306                5-HTP (5-hydroxytryptophan)              NaN
# 315                5-HTP (5-hydroxytryptophan)              NaN
# 343                5-HTP (5-hydroxytryptophan)              NaN
# ...                                        ...              ...
# 391277  Shingrix (zoster vaccine, inactivated)              NaN
# 391296  Shingrix (zoster vaccine, inactivated)              NaN
# 391298  Shingrix (zoster vaccine, inactivated)              NaN
# 391300  Shingrix (zoster vaccine, inactivated)              NaN
# 391312  Shingrix (zoster vaccine, inactivated)              NaN
#
#        MedicineBrandName          MedicineGenericName
# 279                5-HTP          5-hydroxytryptophan
# 293                5-HTP          5-hydroxytryptophan
# 306                5-HTP          5-hydroxytryptophan
# 315                5-HTP          5-hydroxytryptophan
# 343                5-HTP          5-hydroxytryptophan
# ...                  ...                          ...
# 391277          Shingrix  zoster vaccine, inactivated
# 391296          Shingrix  zoster vaccine, inactivated
# 391298          Shingrix  zoster vaccine, inactivated
# 391300          Shingrix  zoster vaccine, inactivated
# 391312          Shingrix  zoster vaccine, inactivated
#
# [6450 rows x 4 columns]

# %%
medicinefor_no_for['MedicineBrandName'].value_counts().index.unique()[:10]
# Out:
# Index(['Yaz', 'Yasmin', 'Geodon', 'Gianvi', 'Nikki', 'Reclast', 'Loryna',
#        'Ocella', 'Triumeq', 'Xiidra'],
#       dtype='object', name='MedicineBrandName')

# %%
medicinefor_no_for.loc[medicinefor_no_for['MedicineUsedFor'].isnull()]
# Out:
#              Medicine  MedicineUsedFor MedicineBrandName MedicineGenericName
# 37      Not Mentioned              NaN               NaN                 NaN
# 99      Not Mentioned              NaN               NaN                 NaN
# 116     Not Mentioned              NaN               NaN                 NaN
# 130     Not Mentioned              NaN               NaN                 NaN
# 138     Not Mentioned              NaN               NaN                 NaN
# ...               ...              ...               ...                 ...
# 392505  Not Mentioned              NaN               NaN                 NaN
# 392506  Not Mentioned              NaN               NaN                 NaN
# 392507  Not Mentioned              NaN               NaN                 NaN
# 392508  Not Mentioned              NaN               NaN                 NaN
# 392509  Not Mentioned              NaN               NaN                 NaN
#
# [14024 rows x 4 columns]

# %%
medicinefor_all = [
    medicinefor_with_name, 
    medicinefor_no_name, 
    medicinefor_no_for
]

medicinefor_cleaned = pd.concat(medicinefor_all).sort_index()

# %%
medicinefor_cleaned.sort_index()
# Out:
#              Medicine   MedicineUsedFor MedicineBrandName MedicineGenericName
# 0                 NaN  Nasal Congestion               NaN                 NaN
# 1                 NaN  Nasal Congestion               NaN                 NaN
# 2                 NaN  Nasal Congestion               NaN                 NaN
# 3                 NaN           Anxiety               NaN                 NaN
# 4                 NaN           Anxiety               NaN                 NaN
# ...               ...               ...               ...                 ...
# 392505  Not Mentioned               NaN               NaN                 NaN
# 392506  Not Mentioned               NaN               NaN                 NaN
# 392507  Not Mentioned               NaN               NaN                 NaN
# 392508  Not Mentioned               NaN               NaN                 NaN
# 392509  Not Mentioned               NaN               NaN                 NaN
#
# [392514 rows x 4 columns]

# %%
## HW: Clean the code above so that it can directly change
##     the data straight from the df, not through other variables.

medicinefor_cleaned[~medicinefor_cleaned.index.isin(df.index)]
# Out:
# Empty DataFrame
# Columns: [Medicine, MedicineUsedFor, MedicineBrandName, MedicineGenericName]
# Index: []

# %% [markdown]
# ### Data Cleaning: `MedicineName`

# %%
mask_mn_1 =  df['MedicineName'].str.contains(' for ')
mask_mn_2 = ~df['MedicineName'].str.contains(' for ')

# %%
## Split `MedicineName` into two parts:

## Treatment 1: `<Brand/GenericName> for <Usage>
medicinename_with_generic = pd.DataFrame(
    df.loc[mask_mn_1, 'MedicineName']
        .str.split(' for ', expand=True, n=1)
).rename(columns={0: "MedicineBrandName", 1: 'MedicineUsedFor'})

medicinename_with_generic[['Medicine', 'MedicineGenericName']] = np.nan

medicinename_with_generic = (
    medicinename_with_generic[[
        'Medicine', 'MedicineUsedFor',
        'MedicineBrandName', 'MedicineGenericName'
    ]]
)

# %%
medicinename_with_generic
# Out:
#         Medicine MedicineUsedFor                     MedicineBrandName  \
# 374          NaN  HIV Infection   Abacavir / dolutegravir / lamivudine
# 375          NaN  HIV Infection   Abacavir / dolutegravir / lamivudine
# 376          NaN  HIV Infection   Abacavir / dolutegravir / lamivudine
# 377          NaN  HIV Infection   Abacavir / dolutegravir / lamivudine
# 378          NaN  HIV Infection   Abacavir / dolutegravir / lamivudine
# ...          ...             ...                                   ...
# 392505       NaN       Insomnia                                ZzzQuil
# 392506       NaN       Insomnia                                ZzzQuil
# 392507       NaN       Insomnia                                ZzzQuil
# 392508       NaN       Insomnia                                ZzzQuil
# 392509       NaN       Insomnia                                ZzzQuil
#
#         MedicineGenericName
# 374                     NaN
# 375                     NaN
# 376                     NaN
# 377                     NaN
# 378                     NaN
# ...                     ...
# 392505                  NaN
# 392506                  NaN
# 392507                  NaN
# 392508                  NaN
# 392509                  NaN
#
# [7315 rows x 4 columns]

# %%
medicinename_with_generic['MedicineBrandName'].value_counts().index.unique()[:10]
# Out:
# Index(['Drospirenone / ethinyl estradiol', 'Yaz', 'Yasmin', 'Ziprasidone',
#        'Zoledronic acid', 'Mavyret', 'Zofran', 'Ibuprofen', 'Rybelsus',
#        'Zolmitriptan'],
#       dtype='object', name='MedicineBrandName')

# %%
pd.DataFrame(medicinename_with_generic['MedicineBrandName'].value_counts())
# Out:
#                                   count
# MedicineBrandName
# Drospirenone / ethinyl estradiol   2521
# Yaz                                 832
# Yasmin                              520
# Ziprasidone                         420
# Zoledronic acid                     312
# ...                                 ...
# Rhinaris                              1
# Rhinocort Allergy                     1
# Ribasphere                            1
# Riomet                                1
# Rilpivirine                           1
#
# [81 rows x 1 columns]

# %%
pd.DataFrame(medicinename_with_generic.loc[
    medicinename_with_generic['MedicineBrandName']
        .str.contains(' / '), 'MedicineBrandName'].value_counts())
# Out:
#                                                     count
# MedicineBrandName
# Drospirenone / ethinyl estradiol                     2521
# Abacavir / dolutegravir / lamivudine                  107
# Acetaminophen / butalbital                             18
# Capsaicin / lidocaine / menthol / methyl salicy...      2
# Resorcinol / sulfur topical                             2
# Hydralazine / hydrochlorothiazide / reserpine           1
# Letrozole / ribociclib                                  1

# %% [markdown]
# As we can see above, there are several data that has more than one composition in `MedicineName`, not to mention the "pharma-esque" name. These are the `MedicineGenericName` and we'll move them out to where it should be.

# %%
data_move_to_generic = medicinename_with_generic.loc[
    medicinename_with_generic['MedicineBrandName']
        .str.contains(' / '), 'MedicineBrandName'].unique()
data_move_to_generic
# Out:
# array(['Abacavir / dolutegravir / lamivudine',
#        'Acetaminophen / butalbital', 'Drospirenone / ethinyl estradiol',
#        'Capsaicin / lidocaine / menthol / methyl salicylate topical',
#        'Hydralazine / hydrochlorothiazide / reserpine',
#        'Letrozole / ribociclib', 'Resorcinol / sulfur topical'],
#       dtype=object)

# %%
# Moving the data with generic name from
# `MedicineBrandName` to `MedicineGenericName`

medicinename_with_generic.loc[
    medicinename_with_generic['MedicineBrandName'].isin(
        data_move_to_generic), 'MedicineGenericName'] = (

medicinename_with_generic.loc[
    medicinename_with_generic['MedicineBrandName'].isin(
        data_move_to_generic), 'MedicineBrandName']

)

medicinename_with_generic.loc[
    medicinename_with_generic['MedicineGenericName'].isin(
        data_move_to_generic), 'MedicineBrandName'] = np.nan

# %%
medicinename_with_generic
# Out:
#         Medicine MedicineUsedFor MedicineBrandName  \
# 374          NaN  HIV Infection                NaN
# 375          NaN  HIV Infection                NaN
# 376          NaN  HIV Infection                NaN
# 377          NaN  HIV Infection                NaN
# 378          NaN  HIV Infection                NaN
# ...          ...             ...               ...
# 392505       NaN       Insomnia            ZzzQuil
# 392506       NaN       Insomnia            ZzzQuil
# 392507       NaN       Insomnia            ZzzQuil
# 392508       NaN       Insomnia            ZzzQuil
# 392509       NaN       Insomnia            ZzzQuil
#
#                          MedicineGenericName
# 374     Abacavir / dolutegravir / lamivudine
# 375     Abacavir / dolutegravir / lamivudine
# 376     Abacavir / dolutegravir / lamivudine
# 377     Abacavir / dolutegravir / lamivudine
# 378     Abacavir / dolutegravir / lamivudine
# ...                                      ...
# 392505                                   NaN
# 392506                                   NaN
# 392507                                   NaN
# 392508                                   NaN
# 392509                                   NaN
#
# [7315 rows x 4 columns]

# %%
pd.DataFrame(medicinename_with_generic['MedicineGenericName'].value_counts())
# Out:
#                                                     count
# MedicineGenericName
# Drospirenone / ethinyl estradiol                     2521
# Abacavir / dolutegravir / lamivudine                  107
# Acetaminophen / butalbital                             18
# Capsaicin / lidocaine / menthol / methyl salicy...      2
# Resorcinol / sulfur topical                             2
# Hydralazine / hydrochlorothiazide / reserpine           1
# Letrozole / ribociclib                                  1

# %%
## Split `MedicineName` into two parts:

## Treatment 2: `<Brand>

medicinename_brand_only = pd.DataFrame(
    df.loc[mask_mn_2, 'MedicineName']
).rename(columns={'MedicineName': 'MedicineBrandName'})

medicinename_brand_only[['Medicine', 
    'MedicineUsedFor', 'MedicineGenericName']] = np.nan

medicinename_brand_only = (
    medicinename_brand_only[[
        'Medicine', 'MedicineUsedFor',
        'MedicineBrandName', 'MedicineGenericName'
    ]]
)

# %%
medicinename_brand_only
# Out:
#         Medicine  MedicineUsedFor                 MedicineBrandName  \
# 0            NaN              NaN  12 Hour Nasal Decongestant Spray
# 1            NaN              NaN  12 Hour Nasal Decongestant Spray
# 2            NaN              NaN  12 Hour Nasal Decongestant Spray
# 3            NaN              NaN                             5-HTP
# 4            NaN              NaN                             5-HTP
# ...          ...              ...                               ...
# 392448       NaN              NaN                          ZzzQuil
# 392449       NaN              NaN                          ZzzQuil
# 392450       NaN              NaN                          ZzzQuil
# 392451       NaN              NaN                          ZzzQuil
# 392452       NaN              NaN                          ZzzQuil
#
#         MedicineGenericName
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 392448                  NaN
# 392449                  NaN
# 392450                  NaN
# 392451                  NaN
# 392452                  NaN
#
# [385195 rows x 4 columns]

# %%
medicinename_brand_only['MedicineBrandName'].value_counts().index.unique()[:10]
# Out:
# Index(['Levonorgestrel ', 'Ethinyl estradiol / norethindrone ',
#        'Etonogestrel ', 'Ethinyl estradiol / norgestimate ',
#        'Ethinyl estradiol / levonorgestrel ', 'Nexplanon ',
#        'Miconazole topical ', 'Sertraline ', 'Escitalopram ', 'Fluoxetine '],
#       dtype='object', name='MedicineBrandName')

# %%
pd.DataFrame(medicinename_brand_only['MedicineBrandName'].value_counts())
# Out:
#                                                     count
# MedicineBrandName
# Levonorgestrel                                       9369
# Ethinyl estradiol / norethindrone                    7273
# Etonogestrel                                         6082
# Ethinyl estradiol / norgestimate                     5343
# Ethinyl estradiol / levonorgestrel                   4708
# ...                                                   ...
# Epsom Salt                                              1
# Nitroprusside                                           1
# Acetaminophen / dextromethorphan / guaifenesin ...      1
# Tiazac                                                  1
# Serevent Diskus                                         1
#
# [4550 rows x 1 columns]

# %%
medicinename_all = [
    medicinename_with_generic,
    medicinename_brand_only
]

medicinename_cleaned = pd.concat(medicinename_all).sort_index()

# %%
medicinename_cleaned
# Out:
#         Medicine MedicineUsedFor                 MedicineBrandName  \
# 0            NaN             NaN  12 Hour Nasal Decongestant Spray
# 1            NaN             NaN  12 Hour Nasal Decongestant Spray
# 2            NaN             NaN  12 Hour Nasal Decongestant Spray
# 3            NaN             NaN                             5-HTP
# 4            NaN             NaN                             5-HTP
# ...          ...             ...                               ...
# 392505       NaN       Insomnia                            ZzzQuil
# 392506       NaN       Insomnia                            ZzzQuil
# 392507       NaN       Insomnia                            ZzzQuil
# 392508       NaN       Insomnia                            ZzzQuil
# 392509       NaN       Insomnia                            ZzzQuil
#
#        MedicineGenericName
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 392505                 NaN
# 392506                 NaN
# 392507                 NaN
# 392508                 NaN
# 392509                 NaN
#
# [392510 rows x 4 columns]

# %% [markdown]
# ### Add the Clean Columns!

# %%
meds_clean = medicinefor_cleaned.fillna(medicinename_cleaned)

for col in meds_clean.columns:
    meds_clean[col] = meds_clean[col].str.title()

meds_clean = meds_clean.fillna('Not Mentioned')

# %%
meds_clean
# Out:
#              Medicine   MedicineUsedFor                 MedicineBrandName  \
# 0       Not Mentioned  Nasal Congestion  12 Hour Nasal Decongestant Spray
# 1       Not Mentioned  Nasal Congestion  12 Hour Nasal Decongestant Spray
# 2       Not Mentioned  Nasal Congestion  12 Hour Nasal Decongestant Spray
# 3       Not Mentioned           Anxiety                             5-Htp
# 4       Not Mentioned           Anxiety                             5-Htp
# ...               ...               ...                               ...
# 392505  Not Mentioned         Insomnia                            Zzzquil
# 392506  Not Mentioned         Insomnia                            Zzzquil
# 392507  Not Mentioned         Insomnia                            Zzzquil
# 392508  Not Mentioned         Insomnia                            Zzzquil
# 392509  Not Mentioned         Insomnia                            Zzzquil
#
#        MedicineGenericName
# 0            Not Mentioned
# 1            Not Mentioned
# 2            Not Mentioned
# 3            Not Mentioned
# 4            Not Mentioned
# ...                    ...
# 392505       Not Mentioned
# 392506       Not Mentioned
# 392507       Not Mentioned
# 392508       Not Mentioned
# 392509       Not Mentioned
#
# [392514 rows x 4 columns]

# %%
meds_clean[~meds_clean.index.isin(df.index)]
# Out:
# Empty DataFrame
# Columns: [Medicine, MedicineUsedFor, MedicineBrandName, MedicineGenericName]
# Index: []

# %%
df = pd.merge(meds_clean, df, left_index=True, right_index=True)
df = df.drop(['Medicine', 'MedicineName', 'MedicineFor'], axis=1)

# %%
df
# Out:
#          MedicineUsedFor                 MedicineBrandName  \
# 0       Nasal Congestion  12 Hour Nasal Decongestant Spray
# 1       Nasal Congestion  12 Hour Nasal Decongestant Spray
# 2       Nasal Congestion  12 Hour Nasal Decongestant Spray
# 3                Anxiety                             5-Htp
# 4                Anxiety                             5-Htp
# ...                  ...                               ...
# 392505         Insomnia                            Zzzquil
# 392506         Insomnia                            Zzzquil
# 392507         Insomnia                            Zzzquil
# 392508         Insomnia                            Zzzquil
# 392509         Insomnia                            Zzzquil
#
#        MedicineGenericName ReviewDate  UserName                   IntakeTime  \
# 0            Not Mentioned  26-Jan-21      xano                Not Specified
# 1            Not Mentioned  19-Aug-22  Breat...       Taken for 1 to 2 years
# 2            Not Mentioned  28-Apr-18       Abe  Taken for less than 1 month
# 3            Not Mentioned   3-May-20    Andres  Taken for less than 1 month
# 4            Not Mentioned  11-Jul-19     Shawn                Not Specified
# ...                    ...        ...       ...                          ...
# 392505       Not Mentioned  23-Sep-20     emano  Taken for less than 1 month
# 392506       Not Mentioned  26-Sep-22  ZzzQu...  Taken for less than 1 month
# 392507       Not Mentioned  12-Jun-20  Annon...                Not Specified
# 392508       Not Mentioned  18-Aug-20    Sleepy  Taken for less than 1 month
# 392509       Not Mentioned  22-May-20     AJano  Taken for less than 1 month
#
#                                                   Reviews  ReviewLength  \
# 0       This is very effective IF you can get the cove...            52
# 1       Actually I use the generic brand of the 12 hou...           319
# 2       Cap took 20 minutes to open process was frustr...           373
# 3       Hi everyone\n'10 / 105-HTPFor Anxiety23129-Oct...           623
# 4       Took SSRI (Prozac) for Anxiety/Depression for ...           156
# ...                                                   ...           ...
# 392505  I hate zzzquill. I took multiple doses one nig...           218
# 392506  Desperately in need of sleep & decided to take...           234
# 392507  I have insomnia for the past several months an...           228
# 392508  I personally wouldn’t recommend this to my wor...           325
# 392509  1st time using ZzzQuil it worked and I was sur...           678
#
#         Rating  NumberOfLikes
# 0            6              0
# 1           10              0
# 2            1              0
# 3           10            345
# 4            9            229
# ...        ...            ...
# 392505       1              8
# 392506       1              3
# 392507       1              8
# 392508       1              6
# 392509       5              6
#
# [392514 rows x 10 columns]

# %%
df['MedicineBrandName'].value_counts()
# Out:
# MedicineBrandName
# Nexplanon           4515
# Nexplanon           4478
# Yaz                 2645
# Plan B One-Step     2491
# Plan B One-Step     2458
#                     ...
# Baricitinib            1
# Magnevist              1
# Prednicot              1
# Sterapred              1
# Monopril               1
# Name: count, Length: 5380, dtype: int64

# %%
df['MedicineBrandName'].value_counts().index.unique()
# Out:
# Index(['Nexplanon', 'Nexplanon ', 'Yaz', 'Plan B One-Step', 'Plan B One-Step ',
#        'Mirena', 'Sertraline ', 'Lexapro', 'Lexapro ', 'Gabapentin ',
#        ...
#        'Praziquantel', 'Dehydroepiandrosterone ',
#        'Bazedoxifene / Conjugated Estrogens', 'Silq Vanilla', 'Demeclocycline',
#        'Baricitinib', 'Magnevist', 'Prednicot', 'Sterapred', 'Monopril'],
#       dtype='object', name='MedicineBrandName', length=5380)

# %%
df.loc[
    df['MedicineBrandName'].str.endswith(' '),
    'MedicineBrandName'].value_counts().index.unique()
# Out:
# Index(['Nexplanon ', 'Plan B One-Step ', 'Sertraline ', 'Lexapro ',
#        'Gabapentin ', 'Phentermine ', 'Miconazole Topical ', 'Zoloft ',
#        'Depo-Provera ', 'Metronidazole ',
#        ...
#        'Ethinyl Estradiol / Segesterone ', 'Tenormin ',
#        'Estradiol / Levonorgestrel ', 'Estazolam ', 'Pramoxine Topical ',
#        'Viloxazine ', 'Mefloquine ', 'Elagolix ', 'Edarbyclor ',
#        'Gemfibrozil '],
#       dtype='object', name='MedicineBrandName', length=1403)

# %%
(df.loc[df['MedicineBrandName']
   .str.endswith(' '), 'MedicineBrandName']) = (
    
 df.loc[df['MedicineBrandName']
   .str.endswith(' '), 'MedicineBrandName']
   .str.rstrip(' ')
    
)

# %%
df.loc[
    df['MedicineBrandName'].str.endswith(' '),
    'MedicineBrandName'].value_counts().index.unique()
# Out:
# Index([], dtype='object', name='MedicineBrandName')

# %%
df['MedicineBrandName'].value_counts()
# Out:
# MedicineBrandName
# Nexplanon                             8993
# Plan B One-Step                       4949
# Lexapro                               4230
# Zoloft                                3557
# Depo-Provera                          3539
#                                       ...
# Cinacalcet                               1
# Stanback Analgesic                       1
# Flumist Quadrivalent                     1
# Bayer Women'S Aspirin With Calcium       1
# Symlinpen 120                            1
# Name: count, Length: 4256, dtype: int64

# %%
df['MedicineUsedFor'].value_counts()
# Out:
# MedicineUsedFor
# Birth Control                                  60144
# Depression                                     19521
# Weight Loss (Obesity/Overweight)               14106
# Anxiety                                        14085
# Pain                                           11261
#                                                ...
# Epididymitis, Non-Specific                         1
# Multiple Endocrine Adenomas                        1
# Hyperlipoproteinemia Type Iib, Elevated Ldl        1
# Occupational Exposure                              1
# Cluster-Tic Syndrome                               1
# Name: count, Length: 1086, dtype: int64

# %% [markdown]
# ## `Reviews`

# %%
pd.options.display.max_colwidth = 1500

# %%
pd.DataFrame(df['Reviews'].head())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Reviews
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
#
# ```
# ## X: Any digit, (...): Optional characters,
# ## <...>: Formattings, {...}: Number of characters
#
# <(\r)\n>'<(X / 10)><MedicineName> <User Reviews & Ratings (Page XX)<MedicineFor>X{1-5}-<Month>{3}-XX(<Name>)(<IntakeTime>)
#
# ## <MedicineName>, <MedicineFor>, <IntakeTime> are
# ## included in other columns, while <Name> doesn't.
#
# ```
#
# We may assume that the users were supposed to hit Enter for a new paragraph, given the `\r\n` in the beginning. However, the whole data are shown instead.
#
# We need to clean it out for the purpose of sentiment analysis so the sentences can be cleanly tokenized. Also there are a sensitive data of actual name placed after the date--we need to maintain the privacy of patients on healthcare data.
#
# Let's clean it by using regular expression or **regex** to encapsulate the format. The process will be a bit tricky since on the optional parts `(<Name>)(<IntakeTime>)`, some reviews have both, some have one part, and others have none at all. We'll be cleaning it in two steps: **(1) the main format, and (2) the optional format.**

# %%
df.loc[df.index == 163266, 'Reviews']
# Out:
# 163266    I am 59 y old male with anxiety on and off since I remember. I work on the computer as a full time job. Last year I had severe tension headache for a month from work related stress. Couldn't drive the car at night panic attacks dizziness vertigo issuebody shaking etc. My GC provider listened to my story. She put me on 10mg fluox for 1 month. First 4 days ok. Then headache started so bad I was ready to give up after a week then 4 sleepless nights in the row. Insane. I had panic attacks\r\n'6 / 10Fluoxetine User Reviews & Ratings (Page 50)Prozac (fluoxetine) for Anxiety and Stress26Anonymous29-Nov-11Was on 10mg for 1 yr... not much change. Switched to 20mg for two weeks then doctor bumped it up to 30mg/day. I think it might help depression but I feel its doing very little to help anxiety. Don't like the idea of having to be dependent on medicines to make me feel normal. Stick with it awhile longer.
# Name: Reviews, dtype: object

# %%
## Regex mask format to clean: 
regex_mask_1 = re.compile(
    "(\\r\\n.+|\\r.+|'\d{1,2} \/ 10.+)(\d{1,6}-.{3}-\d{2})"
)

df['Reviews'] = df['Reviews'].str.replace(regex_mask_1, ' --filtered_1 ', regex=True)

# %%
# index examples:
index_sample = [7659, 209873, 242716, 269576, 198296]
pd.DataFrame(df.loc[df.index.isin(index_sample), 'Reviews'])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Reviews
# 7659                            As a heathcare professional having given Mucomyst to patients over more than 30 year career I've yet to observe any benefit from the aerosolization of this med. I don't want to minimize the previous comments. Used during a bronchoscopy in liquid wash it will dissolve thick mucus quickly and effectively but the benefit of aerosolization has not been demonstrated or established in any controlled study. Also after more than 24 hours of use the lung tissue will begin to weep this is a very caustic substance to lung. Too often it's order for a specific problem area of the lung. As the laws of nature take effect in that gas follows the path of least resistance, Mucomyst is delivered to all areas of lung with minimal effect to the problem. --filtered_1 richardTaken for 6 months to 1 yearI take this for COPD I am wheezing constantly after regular use of NAC cysteine it helps a little reducing mucus but creating a difficulty in breathing and wheezing daily . whereas this did not happen before taking this drug  l revert back to MSM powder with vitamin C liquid and feel better .
# 160       Hi everyone --filtered_1 GannuTaken for less than 1 monthYes it works. I am floating after taking 5-HTP. I take 100 mg after breakfast and 100 mg after dinner. Also I stopped smoking. Good for my anxiety and stress. In the past talking to people was hard. I am shy guy. I think too much which is not at all required. After taking 5-HTP I feel the confidence . I am skinny guy and used to worry people around me is watching. Now I don’t care it’s my life and got my confidence now . I used to get tears automatically while talking to people because of nervousness. 5 HTP gave me my life back . Thanks
# 228                                        So far so good as only on it for about 5 days at 300mg per day. I have combined it with multi vitamin vitamin b complex --filtered_1 anony...This supplement has really worked for me! The only problem is after about a month of taking it I have started experiencing ringing in my ears and pressure headaches. But it does boost my mood and I haven't mood swings or anxiety like before I started taking this. Also I find I haven't been as hungry and eating as much. This supplement would be perfect if I hadn't started having the problems with my ears and the headaches.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 392321                                                                                                                                                                                                                                                                                                                                                                                                                                           I was given zyrtec for cold symptoms --filtered_1 AZJJTaken for 1 to 2 yearsI took this on and off for several years and then recently it started to make me feel like a zombie.
# 392329                                                                                                                                                                                                                                                                                     Extreme itchynes all over body (every body part ) cannot sleep cannot stop itching myself everywhere --filtered_1 PaulaTaken for 1 to 6 monthsThis medication has helped me a lot. I take it only once per day but I notice that after 12 hrs the congestion comes back so I will try it every 12 hrs now. It works very well for me .
# 392346                                                                                                                                                                                                                                                                                                                                                        Had PSA of 70 and Gleason score of 9 January 2021. After Lupron for 9 months --filtered_1 John...Taken for less than 1 monthSevere joint pain after 2 weeks so far. Moves between shoulders elbows hips knees. lasting 2-minutes per joint then moving to the next.
# 392416                                                                                                                                                                                                                                                                I have been having a lot of issues with falling asleep lately --filtered_1 DDeas...Taken for less than 1 monthIf you have actual REAL insomnia ZzzQuil won't do a thing for you; I breathe great when I take it but no sleep. Your best bet would be to contact your doctor for some prescription sleep aids; maybe a sleep study if you got the insurance.
# 392493                                                                                                                                                                                                                                                                I have been having a lot of issues with falling asleep lately --filtered_1 DDeas...Taken for less than 1 monthIf you have actual REAL insomnia ZzzQuil won't do a thing for you; I breathe great when I take it but no sleep. Your best bet would be to contact your doctor for some prescription sleep aids; maybe a sleep study if you got the insurance.
#
# [5218 rows x 1 columns]

# %%
## Checking if there's data that has <IntakeTime> format of <Date>
## e.g.: "...richard2-Nov-16I have consumed the drug since ..."

regex_check = re.compile(' --filtered_1 .+ (\d{1,2}-.{3}-\d{2})')
pd.DataFrame(df.loc[df['Reviews'].str.contains(regex_check), 'Reviews'])
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_25736\2865714221.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   pd.DataFrame(df.loc[df['Reviews'].str.contains(regex_check), 'Reviews'])
# Empty DataFrame
# Columns: [Reviews]
# Index: []

# %%
pd.DataFrame(
    df.loc[df['Reviews']
           .str.contains(' --filtered_1 '), 
              'Reviews']).sample(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Reviews
# 373872                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        I have used OTC Pataday once daily for allergy eyes for the past 5 days. For me --filtered_1 A Cli...Beware! The actual product is TINY. The package makes it look bigger. In fact the lid is larger than the bottle! I don't feel it is a good value.
# 78362                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    I did like this medications at first but had to stop after reaching my full dosage because I broke out in severe hives. It takes several weeks to build up to the max dose. On the 3rd week --filtered_1 Nana...Taken for 1 to 6 monthsI'm 48 and 5ft 2 and suffer from low thyroid issues.
# 119085                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Entyvio did help me took almost 2 years but now they won't help with insurance copay and I cannot take it any more it is way to expensive --filtered_1 Farme...Taken for 6 months to 1 yearBeen on this for just under a year now and seems to be doing the trick.
# 363872                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             I was on Entyvio for 6 months. I had no symptoms during my loading doses and then it hit me like a rock! I have episodes of stroke like symptoms. My hands would get sweaty I get to where I feel like I'm going to pass out lightheaded --filtered_1 MjanoI used entyvio for around 9 months for ulcerative Colitis. Not only did I lose ALL of my hair 2 years later it has not grown back. I am bald on the top right and entire back of my head. I also lost my eyebrow hair and leg hair. I had no results with this drug and now I am devastated and depressed from being permanently bald.

# %% [markdown]
# We've made a tag on cleaned main format as `--filtered_1 `.
#
# ### Insights for Cleaning `Reviews`
#
# To clean the optional formats, we're going into two steps:
#
# * Make another regex for complete optional format of `(<Name>)(<IntakeTime>)`,
# * and after that clean the ` --filtered_1` for the rest of data.
#
# But here's the tricky part. From observation, we've come to conclusion that `(<Name>)` has a total of 3-10 characters, followed without whitespace by the first word of a new paragraph (capitalized) and then whitespace before the second word.
#
# However, the `(<Name>)` varies in cases. It could be:
#
# * Capitalized such as `Hope` and `Anonymous`,
# * all lowercase such as `richard` and ,
# * mixed characters such as `CarlyP`, `Kirsten...` and `Lc122...`,
# * or all uppercase such as `JAM` and `LJRI`.
#
# Given the limitless combinations from the `(<Name>)`, to include all of this in Regex would be impossible. By that we need to make some sacrifice on the first word. These words include `I`, `After`, `At (first)` or even the `(<BrandName>)` itself, which has been written on the previous paragraph. In Tokenizer, these are called `stopwords`; inconsequential words with little value in Natural Language Processing (NLP).
#
# Given that :
# * We have to hide the personal information on healthcare data,
# * NLP is one project the author is leading to,
# * and we're dealing with less chunks of data (`5014/392514` or `~1.277%`),
#
# The author decides to do the second step by cleaning the rest of data with the first word. We may inevitably clean an important word explaining the review, but the data only covers 1% of the total so the accuracy for NLP later on will not impact as much.

# %%
regex_group_1 = re.compile(
    '( --filtered_1 )(.+[^A-Z])(Taken for (less than 1 month|1 to 6 months|6 months to 1 year|1 to 2 years|10 years or more)?)'
)

regex_group_2 = re.compile(' --filtered_1 (.+?) ')

# %%
# Replace it with `. ` to start a new sentence.

df['Reviews'] = df['Reviews'].str.replace(regex_group_1, '. ', regex=True)
df['Reviews'] = df['Reviews'].str.replace(regex_group_2, '. ', regex=True)

# %%
pd.DataFrame(
    df.loc[df['Reviews']
           .str.contains(' --filtered_1 '), 
              'Reviews'])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Reviews
# 37311                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               I took Belviq XR for 3 weeks. My hands & feet started swelling --filtered_1 Walking...I
# 146703  I've been taking Mono-Linyah for 5 months now and I am so disappointed and unhappy with it. I get frequent headaches they last all day sometimes they last for 2-3 days at a time They're almost unbearable. My periods have gotten even heavier than they were before I started taking this and they last for about 6 or 7 days. I just got off my period 5 days ago and I'm back on it again right now. I have had a period literally every other week since I started taking Mono-linyah. Most people notice weight gain while taking most birth controls --filtered_1 Natal...I
# 252555                                                                                                                                                                                                                                                                                                                                                                                                                                     I have been on this pill a little over a month now. This is the first birth control pill I've ever been on. So far --filtered_1 atxMonsternessa.
# 279307                                                                                         Roxicodone is the most effective pain medication I've had so far. 20 mg every 4 hours. Also 25 mcg patches of Fentanyl. I'm stage 4 with bone cancer and am a recent 'incomplete quadriplegic' from a cervical spinal cord injury but learned to walk again. I'll take the cancer any day over the paralysis. I was taking 4mg of Dilaudid every 4 hours in rehab which was debilitating (to me). I'm starting to build up a tolerance to roxicodone --filtered_1 Anonymous0016unregistered:
# 287334                                                                                                                                                                                                                                                                                                                                                                     I have been getting cold sores for years. I got a tube of Penciclovir once I felt the tell tail tingle and after 5 days it had gone it didn't even blister. I only paid R 60.00 for it --filtered_1 sangaRelief!
# 315859                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               My son was put on this mediicne when he was ten --filtered_1 HORRIBLE!

# %%
# Clean the rest ` -- filtered_1 `, which are placed
# before the second paragraph with only one sentence; 
# no whitespace at the end.

regex_residue = re.compile(' --filtered_1 (.+)')

df['Reviews'] = df['Reviews'].str.replace(regex_residue, '. ', regex=True)

# %%
pd.DataFrame(
    df.loc[df['Reviews']
           .str.contains(' --filtered_1 '), 
              'Reviews'])
# Out:
# Empty DataFrame
# Columns: [Reviews]
# Index: []

# %% [markdown]
# ## Final Touch: Drop Duplicates

# %%
pd.options.display.max_colwidth = 50

# %%
df.sort_values(['NumberOfLikes', 'ReviewLength', 'Rating'], ascending=False)[:20]
# Out:
#                          MedicineUsedFor MedicineBrandName  \
# 160841                        Depression            Prozac
# 305810                        Depression            Prozac
# 160864                        Depression            Prozac
# 386906                        Depression            Zoloft
# 324768                        Depression            Zoloft
# 324769                Anxiety And Stress        Sertraline
# 120404                           Anxiety           Lexapro
# 205637                           Anxiety           Lexapro
# 280798                     Not Mentioned           Ozempic
# 321967                     Not Mentioned           Ozempic
# 195197           Emergency Contraception   Plan B One-Step
# 292376           Emergency Contraception   Plan B One-Step
# 288604  Weight Loss (Obesity/Overweight)          Adipex-P
# 71808                            Anxiety          Cymbalta
# 109294                           Anxiety          Cymbalta
# 192646                Female Infertility         Letrozole
# 48322                         Depression     Wellbutrin Xl
# 375630                        Depression     Wellbutrin Xl
# 52729                            Anxiety            Buspar
# 53312                            Anxiety            Buspar
#
#        MedicineGenericName ReviewDate  UserName                    IntakeTime  \
# 160841          Fluoxetine  20-Aug-20  READT...                 Not Specified
# 305810       Not Mentioned  20-Aug-20  READT...                 Not Specified
# 160864          Fluoxetine  20-Aug-20  READT...                 Not Specified
# 386906       Not Mentioned   9-Sep-19  Saved...                 Not Specified
# 324768          Sertraline   9-Sep-19  Saved...                 Not Specified
# 324769       Not Mentioned  26-Jan-20  Feari...       Taken for 1 to 6 months
# 120404        Escitalopram   4-Sep-20      oksy        Taken for 1 to 2 years
# 205637       Not Mentioned   4-Sep-20      oksy        Taken for 1 to 2 years
# 280798       Not Mentioned  26-Sep-20      dana   Taken for less than 1 month
# 321967         Semaglutide  26-Sep-20      dana   Taken for less than 1 month
# 195197      Levonorgestrel  25-May-21  Anony...                 Not Specified
# 292376       Not Mentioned  25-May-21  Anony...                 Not Specified
# 288604         Phentermine  12-Apr-17  Miche...                 Not Specified
# 71808        Not Mentioned   6-Jan-19    Boomer       Taken for 5 to 10 years
# 109294          Duloxetine   6-Jan-19    Boomer       Taken for 5 to 10 years
# 192646       Not Mentioned  31-Aug-20  Lucky...                 Not Specified
# 48322            Bupropion  19-Oct-20       Max  Taken for 6 months to 1 year
# 375630       Not Mentioned  19-Oct-20       Max  Taken for 6 months to 1 year
# 52729        Not Mentioned  25-Feb-20    Better       Taken for 1 to 6 months
# 53312            Buspirone  25-Feb-20    Better       Taken for 1 to 6 months
#
#                                                   Reviews  ReviewLength  \
# 160841  Even though I always said I was never going to...           487
# 305810  Even though I always said I was never going to...           487
# 160864  Even though I always said I was never going to...           487
# 386906  I’m 36 and I’ve dealt with depression my entir...           186
# 324768  I’m 36 and I’ve dealt with depression my entir...           186
# 324769   I would literally re read the high rated reviews            48
# 120404  I want to thank the people here that have shar...           379
# 205637  I want to thank the people here that have shar...           379
# 280798  Started taking this medication off label for w...           529
# 321967  Started taking this medication off label for w...           529
# 195197  I swore that I would come back to this website...          1046
# 292376  I swore that I would come back to this website...          1046
# 288604  I took Adipex for 1 year and lost 90lbs. I cha...           717
# 71808   Don’t let the negative comments on here scare ...           172
# 109294  Don’t let the negative comments on here scare ...           172
# 192646  I have been trying to get pregt for about 1 ye...           440
# 48322   Real and honest review. I’m a 52 yo male livin...           130
# 375630  Real and honest review. I’m a 52 yo male livin...           130
# 52729   Buspar from what I read is for anxiety directl...           608
# 53312   Buspar from what I read is for anxiety directl...           608
#
#         Rating  NumberOfLikes
# 160841      10           3555
# 305810      10           3555
# 160864      10           3545
# 386906      10           3199
# 324768      10           3190
# 324769      10           2767
# 120404      10           2336
# 205637      10           2336
# 280798       9           2305
# 321967       9           2300
# 195197      10           2114
# 292376      10           2114
# 288604      10           2067
# 71808       10           1949
# 109294      10           1949
# 192646       9           1871
# 48322       10           1754
# 375630      10           1754
# 52729       10           1747
# 53312       10           1747

# %% [markdown]
# You may notice in the first showcase, that there are data duplicates. We're dropping it at last given that all columns have been sorted.

# %%
df = (df.sort_values(
            ['NumberOfLikes', 'ReviewLength', 'Rating',
             'MedicineBrandName', 'MedicineUsedFor'], 
              ascending=[False, False, False, True, True])
        .drop_duplicates(
            subset=['UserName', 'ReviewDate', 'MedicineBrandName', 
                    'MedicineUsedFor', 'ReviewLength'], 
              keep='first')
        .sort_values(['ReviewDate'], ignore_index=True)
)

# %%
df
# Out:
#              MedicineUsedFor             MedicineBrandName  \
# 0                      Cough       Acetaminophen / Codeine
# 1                      Cough                   Benzonatate
# 2        Dermatologic Lesion  Methylprednisolone Dose Pack
# 3         Hypogonadism, Male                      Androgel
# 4                 Depression                        Celexa
# ...                      ...                           ...
# 255945         Birth Control                      Isibloom
# 255946   Underactive Thyroid                     Unithroid
# 255947   Bacterial Infection     Amoxicillin / Clavulanate
# 255948          Strep Throat                     Augmentin
# 255949  Erectile Dysfunction                    Sildenafil
#
#                     MedicineGenericName ReviewDate   UserName  \
# 0                         Not Mentioned   1-Apr-08     smoore
# 1                         Not Mentioned   1-Apr-08  Anonymous
# 2                    Methylprednisolone   1-Apr-08  Anonymous
# 3                         Not Mentioned   1-Apr-08   MikeC...
# 4                         Not Mentioned   1-Apr-08    Cherpie
# ...                                 ...        ...        ...
# 255945  Desogestrel / Ethinyl Estradiol   9-Sep-22     Skylar
# 255946                    Levothyroxine   9-Sep-22        Syd
# 255947                    Not Mentioned   9-Sep-22     FLgirl
# 255948        Amoxicillin / Clavulanate   9-Sep-22   peein...
# 255949                    Not Mentioned   9-Sep-22   rando...
#
#                          IntakeTime  \
# 0                     Not Specified
# 1                     Not Specified
# 2                     Not Specified
# 3                     Not Specified
# 4                     Not Specified
# ...                             ...
# 255945                Not Specified
# 255946  Taken for less than 1 month
# 255947  Taken for less than 1 month
# 255948  Taken for less than 1 month
# 255949  Taken for less than 1 month
#
#                                                   Reviews  ReviewLength  \
# 0                      Works good as a cough suppressant.            34
# 1       Pneumonia cough was non-stop - gave almost ins...           210
# 2       This steriod helped kill the pain of my condit...           162
# 3       I'm a 35 year old male and I had no idea that ...           105
# 4                   It is so nice to have my life back!!!            37
# ...                                                   ...           ...
# 255945  This birth control is awful severe nausea and ...           108
# 255946  Post partial thyroidectomy due to a large beni...           224
# 255947  I was given this for a tooth abscess. I was sc...           957
# 255948  This stuff is great if you wanna pee out of yo...           263
# 255949  I'm 53 now and can't recall when my penis and ...           489
#
#         Rating  NumberOfLikes
# 0            9             24
# 1            9             39
# 2            8             24
# 3            9            380
# 4           10            206
# ...        ...            ...
# 255945       1              0
# 255946       2              7
# 255947       9              1
# 255948       1              0
# 255949      10              2
#
# [255950 rows x 10 columns]

# %% [markdown]
# The data went down from 392514 to 255950 rows--seems like there are a lot of duplicates. With a handful of subset, the data should've dropped the duplicates well. So hey, data's now clean!

# %% [markdown]
# ## Outro
#
# In this section, we have cleaned data from `DrugReviews.csv` through:
#
# * Changing the date-formatted values in `IntakeTime` into `Not Specified`,
# * Sorting the mixed classifications of drugs into its sorted columns of `MedicineUsedFor`, `MedicineBrandName`, and `MedicineGenericName`, and
# * Cleaning glitched characters on `Reviews` for visualization and machine learning purposes.

# %% [markdown]
# ## Next Section
#
# In the next section, we will proceed into two types of project:
#
# * **Drug Recommendations Dashboard from Customer Reviews**, and
# * **Sentiment Analysis of Customer Reviews in Drug Medications**
#
# We need to save the cleaned data beforehand to be used on both.

# %%
df.to_csv('DrugReviews_cleaned.csv', index=False)
